# %% [markdown]
# Importamos las dependencias

# %%
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Cargamos desde el repositorio de github los datos

# %%
url = 'https://github.com/Alf-caput/P1_MineriaDeDatos/raw/main/P3_ReduccionDimensionalidad/USA.xlsx'
df = pd.read_excel(url)
df.head()
# Out:
#           Ciudad   SO2  Neg.Temp  Empresas  Poblacion  Viento  Precip   Dias
# 0        Phoenix  10.0      70.3     213.0      582.0     6.0    7.05   36.0
# 1    Little Rock  13.0      61.0      91.0      132.0     8.2   48.52  100.0
# 2  San Francisco  12.0      56.7     453.0      716.0     8.7   20.66   67.0
# 3         Denver  17.0      51.9     454.0      515.0     9.0   12.95   86.0
# 4       Hartford  56.0      49.1     412.0      158.0     9.0   43.37  127.0

# %% [markdown]
# Con df.info() podemos ver el tamaño del dataset, valores no nulos y tipos de las variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ciudad     41 non-null     object
#  1   SO2        41 non-null     float64
#  2   Neg.Temp   41 non-null     float64
#  3   Empresas   41 non-null     float64
#  4   Poblacion  41 non-null     float64
#  5   Viento     41 non-null     float64
#  6   Precip     41 non-null     float64
#  7   Dias       41 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 2.7+ KB

# %% [markdown]
# Se trata de un set de datos sobre ciudades, las variables del mismo son:

# %%
df.columns
# Out:
# Index(['Ciudad', 'SO2', 'Neg.Temp', 'Empresas', 'Poblacion', 'Viento',
#        'Precip', 'Dias'],
#       dtype='object')

# %% [markdown]
# Parece que tiene que ver con mediciones del ambiente y demografía en ciudades.\
# Buscando documentación online encontramos el valor de los datos:
# - Ciudad, nombre de ciudad (EEUU)
# - SO2, contenido en SO2
# - Neg.Temp, temperatura Fahrenheit
# - Empresas, número de empresas con más de 20 trabajadores
# - Poblacion, en miles de habitantes
# - Viento, velocidad media del viento
# - Precip, precipitación anual media
# - Dias, número de días lluviosos al año

# %% [markdown]
# Con df.info() se podía ver que el número de no nulos coincide con el número de filas, no obstante para datasets más grandes podríamos comprobar el número de NA con:

# %%
pd.DataFrame({'Valores NA': df.isna().sum()})
# Out:
#            Valores NA
# Ciudad              0
# SO2                 0
# Neg.Temp            0
# Empresas            0
# Poblacion           0
# Viento              0
# Precip              0
# Dias                0

# %% [markdown]
# En df.info() nos fijamos que son float64 excepto los valores que toma la variable ciudad que son strings (pandas por defecto considera strings como tipo obj)\
# A simple vista parece que las ciudades del dataset son únicas, lo podemos comprobar:

# %%
df.loc[:, 'Ciudad'].nunique() == len(df.loc[:, 'Ciudad'])
# Out:
# True

# %% [markdown]
# Utilizaremos el nombre de la ciudad como índice de fila (es conveniente para estandarizar el resto de variables)

# %%
df = df.set_index('Ciudad')
df.head()
# Out:
#                 SO2  Neg.Temp  Empresas  Poblacion  Viento  Precip   Dias
# Ciudad
# Phoenix        10.0      70.3     213.0      582.0     6.0    7.05   36.0
# Little Rock    13.0      61.0      91.0      132.0     8.2   48.52  100.0
# San Francisco  12.0      56.7     453.0      716.0     8.7   20.66   67.0
# Denver         17.0      51.9     454.0      515.0     9.0   12.95   86.0
# Hartford       56.0      49.1     412.0      158.0     9.0   43.37  127.0

# %% [markdown]
# Para hacernos una idea de los datos y ver rangos usamos .describe()\
# Nota: Eliminamos la columna conteo y transponemos para que quede más legible

# %%
df.describe().drop('count').T
# Out:
#                  mean         std    min     25%     50%     75%     max
# SO2         30.048780   23.472272   8.00   13.00   26.00   35.00   110.0
# Neg.Temp    55.763415    7.227716  43.50   50.60   54.60   59.30    75.5
# Empresas   463.097561  563.473948  35.00  181.00  347.00  462.00  3344.0
# Poblacion  608.609756  579.113023  71.00  299.00  515.00  717.00  3369.0
# Viento       9.443902    1.428644   6.00    8.70    9.30   10.60    12.7
# Precip      36.769024   11.771550   7.05   30.96   38.74   43.11    59.8
# Dias       113.902439   26.506419  36.00  103.00  115.00  128.00   166.0

# %% [markdown]
# Por una parte no observamos valores carentes de sentido, como una cantidad de días negativa o una tempertatura extraña.

# %% [markdown]
# Por otro lado como no conocemos bien el dominio del problema y no contamos con gran cantidad de datos, no eliminaremos posibles outliers, que podemos observar con boxplots:

# %%
fig, axs = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(15, 5))

for i, columna in enumerate(df.columns):
    axs[i].boxplot(df[columna])
    axs[i].set_title(columna)

plt.tight_layout()

plt.show()

# %% [markdown]
# Para poder interpretar los resultados de forma correcta, se realizará una breve explicación sobre el rango intercuartílico(IQR).El IQR abarca el rango medio del conjunto de datos, representando el 50% central de las observaciones.
#
#  En un gráfico de cajas, la "caja" en sí representa el rango intercuartílico. La línea que divide la caja en dos partes es la mediana (Q2), que indica la posición central de los datos. Las "líneas whisker" (bigotes) que se extienden desde la caja representan el rango completo de los datos, excluyendo valores extremos o atípicos. ¿Y como se determinan dichos valores extremos o atípicos?
#
# IQR = Q3 - Q1
#
# Una vez determinado el IQR, se empleará "la regla de los 1.5* IQR". Esto es: cualquier valor que esté por debajo del primer cuartil menos el rango intercuartílico por 1.5 (Q1-IQR*1.5) y cualquier valor que este por encima del tercer cuartil más el rango intercuartílico por 1.5 (Q3 + IQR*1.5).
#
# En suma, cualquier valor que cumpla dichas condiciones representa un valor significativamente alejado de la mayoría del conjunto de datos.
#
# Calculamos las fronteras a partir de las cuales categorizamos outliers utilizando el "método de los bigotes"

# %% [markdown]
# ### 1.- (1 punto) Estandarizar los datos

# %% [markdown]
# Estandarizamos el dataframe, para pasar todas las variables al mismo rango, para ello nos serviremos de un objeto scaler obtenido de sklearn.preprocessing.StandardScaler\
# Los nuevos datos estandarizados se meten en un nuevo pandas.DataFrame

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_std = scaler.fit_transform(df)

df_std = pd.DataFrame(df_std, columns=df.columns, index=df.index)
df_std.head()
# Out:
#                     SO2  Neg.Temp  Empresas  Poblacion    Viento    Precip  \
# Ciudad
# Phoenix       -0.864758  2.036213 -0.449363  -0.046520 -2.440555 -2.556012
# Little Rock   -0.735360  0.733515 -0.668567  -0.833224 -0.881504  1.010653
# San Francisco -0.778493  0.131192 -0.018143   0.187743 -0.527174 -1.385471
# Denver        -0.562829 -0.541168 -0.016346  -0.163651 -0.314576 -2.048577
# Hartford       1.119347 -0.933378 -0.091810  -0.787770 -0.314576  0.567723
#
#                    Dias
# Ciudad
# Phoenix       -2.975514
# Little Rock   -0.531009
# San Francisco -1.791457
# Denver        -1.065744
# Hartford       0.500266

# %% [markdown]
# Generamos estadísticas con .describe().\
# (Para que se muestren resultados con 2 decimales se usa un context manager que cambia la configuración del display y una vez se termina el bloque with devuelve a la configuración inicial)

# %%
class Notation2Decimal:
    def __enter__(self):
        self.original_config = pd.get_option('display.float_format')
        pd.set_option('display.float_format', lambda x: '%.2f' % x)

    def __exit__(self, exc_type, exc_value, traceback):
        pd.set_option('display.float_format', self.original_config)

with Notation2Decimal():
    print(df_std.describe().drop('count').T)
# Out:
#            mean  std   min   25%   50%   75%  max
# SO2        0.00 1.01 -0.95 -0.74 -0.17  0.21 3.45
# Neg.Temp   0.00 1.01 -1.72 -0.72 -0.16  0.50 2.76
# Empresas  -0.00 1.01 -0.77 -0.51 -0.21 -0.00 5.18
# Poblacion -0.00 1.01 -0.94 -0.54 -0.16  0.19 4.83
# Viento     0.00 1.01 -2.44 -0.53 -0.10  0.82 2.31
# Precip     0.00 1.01 -2.56 -0.50  0.17  0.55 1.98
# Dias      -0.00 1.01 -2.98 -0.42  0.04  0.54 1.99

# %% [markdown]
# Vemos que las variables se encuentran en un rango con media 0 y desviación típica 1.\
# (No son exactos por problemas de redondeo)

# %% [markdown]
# ### 2.- (1 punto) Obtención de autovalores y autovectores

# %%
df_std.head()
# Out:
#                     SO2  Neg.Temp  Empresas  Poblacion    Viento    Precip  \
# Ciudad
# Phoenix       -0.864758  2.036213 -0.449363  -0.046520 -2.440555 -2.556012
# Little Rock   -0.735360  0.733515 -0.668567  -0.833224 -0.881504  1.010653
# San Francisco -0.778493  0.131192 -0.018143   0.187743 -0.527174 -1.385471
# Denver        -0.562829 -0.541168 -0.016346  -0.163651 -0.314576 -2.048577
# Hartford       1.119347 -0.933378 -0.091810  -0.787770 -0.314576  0.567723
#
#                    Dias
# Ciudad
# Phoenix       -2.975514
# Little Rock   -0.531009
# San Francisco -1.791457
# Denver        -1.065744
# Hartford       0.500266

# %% [markdown]
# Sobre el dataframe estandarizado (df_std) obtenemos la matriz de correlación (df_corr)

# %%
df_corr = df_std.corr()
df_corr
# Out:
#                 SO2  Neg.Temp  Empresas  Poblacion    Viento    Precip  \
# SO2        1.000000 -0.433600  0.644769   0.493780  0.094690  0.054294
# Neg.Temp  -0.433600  1.000000 -0.190042  -0.062678 -0.349740  0.386253
# Empresas   0.644769 -0.190042  1.000000   0.955269  0.237947 -0.032417
# Poblacion  0.493780 -0.062678  0.955269   1.000000  0.212644 -0.026119
# Viento     0.094690 -0.349740  0.237947   0.212644  1.000000 -0.012994
# Precip     0.054294  0.386253 -0.032417  -0.026119 -0.012994  1.000000
# Dias       0.369564 -0.430242  0.131829   0.042083  0.164106  0.496097
#
#                Dias
# SO2        0.369564
# Neg.Temp  -0.430242
# Empresas   0.131829
# Poblacion  0.042083
# Viento     0.164106
# Precip     0.496097
# Dias       1.000000

# %% [markdown]
# Usando la librería seaborn podemos con una línea de código mostrar las correlaciones de manera gráfica

# %%
import seaborn as sns
sns.heatmap(df_corr, cmap='RdBu', vmin=-1, vmax=1, annot=True)
plt.title('Mapa de Calor - Matriz de Correlación')
plt.show()

# %% [markdown]
# Para obtener los autovalores y autovectores utilizamos linalg.eig de numpy, una vez obtenidos los reordenamos de mayor a menor:

# %%
eigenvalues, eigenvectors = np.linalg.eig(df_corr.values)
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]
eigenvalues
# Out:
# array([2.72811968, 1.51233485, 1.39497299, 0.89199129, 0.34677866,
#        0.10028759, 0.02551493])

# %% [markdown]
# Calculamos la varianza explicada (y su acumulación) por cada una de las nuevas componentes y lo mostramos en un dataframe

# %%
variance_perc = (eigenvalues * 100 / np.sum(eigenvalues))
acc_variance_perc = np.cumsum(variance_perc)
comp_index = pd.Index((f'PC{i+1}' for i in range(len(eigenvalues))), name='Componentes')

df_variance = pd.DataFrame({
    'Autovalor': eigenvalues,
    'Varianza explicada(%)': variance_perc,
    'Varianza acumulada(%)': acc_variance_perc},
    index=comp_index)

with Notation2Decimal():
    print(df_variance)
# Out:
#              Autovalor  Varianza explicada(%)  Varianza acumulada(%)
# Componentes
# PC1               2.73                  38.97                  38.97
# PC2               1.51                  21.60                  60.58
# PC3               1.39                  19.93                  80.51
# PC4               0.89                  12.74                  93.25
# PC5               0.35                   4.95                  98.20
# PC6               0.10                   1.43                  99.64
# PC7               0.03                   0.36                 100.00

# %% [markdown]
# Gráficamente se entiende de manera más intuitiva:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

x = df_variance.index
y = df_variance.loc[:, 'Varianza explicada(%)']
y_cum = df_variance.loc[:, 'Varianza acumulada(%)']

ax = y_cum.plot(kind='bar', color='lime', alpha=0.3)
for i, valor in enumerate(y_cum):
    plt.text(i, valor, f'{valor:.2f}%', ha='center', va='bottom')

ax = y.plot(kind='bar')
for i, valor in enumerate(y):
    # Acumulada[0] == Individual[0] omit first Acumulada
    if i:
        plt.text(i, valor, f'{valor:.2f}%', ha='center', va='bottom')

# Rotate labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)

plt.xlabel('Componente')
plt.ylabel('Varianza explicada(%)')
plt.title('PCA - Varianza explicada')
plt.legend(['Varianza acumulada', 'Varianza individual'], loc='best')
plt.show()

# %% [markdown]
# ¿Cuánta información perdemos con 2 componentes?

# %%
num_comp = 2
info_loss = 100-df_variance.loc[f"PC{num_comp}", "Varianza acumulada(%)"]
print(f'Con {num_comp} componentes perdemos un {info_loss:.2f}%')
# Out:
# Con 2 componentes perdemos un 39.42%

# %% [markdown]
# ¿Cuánta información representamos con 3 componentes?

# %%
num_comp = 3
info = df_variance.loc[f"PC{num_comp}", "Varianza acumulada(%)"]
print(f'Con {num_comp} componentes representamos un {info:.2f}%')
# Out:
# Con 3 componentes representamos un 80.51%

# %% [markdown]
# ##### 3.- (1 punto)Obtén un diagrama de dispersión en 3 dimensiones y comenta qué has interpretado en él. Elige al menos 4 ciudades de forma aleatoria y explica qué pasa con ellas.

# %% [markdown]
# En coordenadas de las 3 primeras componentes principales los datos quedan como sigue:

# %%
num_comp = 3
comp_index = pd.Index(f'PC{i+1}' for i in range(num_comp))

df_pca = pd.DataFrame(
    data=np.dot(df_std, eigenvectors[:, :num_comp]),
    columns=comp_index,
    index=df_std.index)

with Notation2Decimal():
    print(df_pca.head())
# Out:
#                 PC1   PC2   PC3
# Ciudad
# Phoenix       -2.72 -3.89 -1.06
# Little Rock   -1.72  0.48 -0.85
# San Francisco -0.94 -2.24  0.18
# Denver        -0.55 -1.97  1.23
# Hartford       0.46  1.10  0.59

# %% [markdown]
# Si elegimos 3 componentes principales los 3 autovectores asociados nos dan información sobre las variables iniciales

# %%
num_comp = 3
comp_index = pd.Index(f'PC{i+1}' for i in range(num_comp))

df_3eig = pd.DataFrame(data=eigenvectors[:, :num_comp], index=df_std.columns, columns=comp_index)
with Notation2Decimal():
    print(df_3eig)
# Out:
#             PC1   PC2   PC3
# SO2        0.49  0.08 -0.01
# Neg.Temp  -0.32 -0.09 -0.68
# Empresas   0.54 -0.23 -0.27
# Poblacion  0.49 -0.28 -0.34
# Viento     0.25  0.06  0.31
# Precip     0.00  0.63 -0.49
# Dias       0.26  0.68  0.11

# %% [markdown]
# Podemos representar las componentes principales contra sí mismas, en 2 dimensiones

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].scatter(df_pca['PC1'], df_pca['PC2'], color='lightblue')
for i, variable in enumerate(df_std.columns):
    x, y, z = np.zeros(3)
    u, v, w = eigenvectors[i, :3] * 3
    axs[0].arrow(x, y, u, v, color='r', alpha=0.7, head_width=0.05, head_length=0.05)
    axs[0].text(u, v, variable, color='k', ha='right', va='bottom', fontsize=8)
    axs[0].set_xlabel('PC1')
    axs[0].set_ylabel('PC2')

axs[1].scatter(df_pca['PC1'], df_pca['PC3'], color='lightblue')
for i, variable in enumerate(df_std.columns):
    x, y, z = np.zeros(3)
    u, v, w = eigenvectors[i, :3] * 3
    axs[1].arrow(x, z, u, w, color='r', alpha=0.7, head_width=0.05, head_length=0.05)
    axs[1].text(u, w, variable, color='k', ha='right', va='bottom', fontsize=8)
    axs[1].set_xlabel('PC1')
    axs[1].set_ylabel('PC3')

axs[2].scatter(df_pca['PC2'], df_pca['PC3'], color='lightblue')
for i, variable in enumerate(df_std.columns):
    x, y, z = np.zeros(3)
    u, v, w = eigenvectors[i, :3] * 3
    axs[2].arrow(y, z, v, w, color='r', alpha=0.7, head_width=0.05, head_length=0.05)
    axs[2].text(v, w, variable, color='k', ha='right', va='bottom', fontsize=8)
    axs[2].set_xlabel('PC2')
    axs[2].set_ylabel('PC3')

# %% [markdown]
# A partir de los gráficos se puede realizar un análisis de diferentes elementos que proporcionan mucha información sobre los componentes principales.
#
# Las flechas en cada gráfico representan los autovectores asociados a las variables originales del conjunto de datos y la dirección de cada flecha indica la dirección de máxima variación en los datos.
# La longitud de cada flecha indica la magnitud de la varianza explicada por esa variable en la dirección correspondiente.
#
# Nos ubicamos en el primer gráfico (PC1 y PC2), la dirección y longitud de cada flecha indican la contribución de cada variable a la variabilidad a lo largo de PC1 y PC2.
# Se puede observar que las flechas más pronunciadas son "Dias" (dias lluviosos al año) y "Precip" (precipitación anual media) cuya orientación es PC2; lo cual indica que PC2 representa principalmente la variabilidad de "Dias" y "Precip". Asimismo, se puede observar una correlación moderada entre ambas variables y una ligera relación  inversa con las variables "Empresas" (número de empresas con más de 20 trabajadores) y "Población" (en miles de habitantes) cuya representatividad recae principalmente en PC1.
#
# Por otro lado PC1, cuyos parametros principales son "Empresas", "Población" "SO2" (contenido en SO2) y "Neg. Temp" (temperatura Fahrenheit) de forma inversa, nos indica precisamente la relación inversa entre "Neg.Temp" y el resto de sus variables. Es especialmente notable la correlación inversa entre la temperatura negativa y el viento, el contenido en S02 y los días lluviosos; lo cual quiere decir que en las ciudades más frias hay ausencia de viento y lluvia, y el contenido en S02 es más bajo. También es notable la fuerte correlación entre empresas, población y SO2 (especialmente entre empresas y población) es decir, a mayor población mayor número de empresas y contenido en SO2.
#
#
# El segundo gráfico compara PC1 y PC3. En este gráfico las flechas de mayor variabilidad son "Neg.Temp" y "Viento" (que muestran una fuerte correlación inversa). Asimismo se puede apreciar mejor la correlación entre otros parametros como "Precip" y "Neg.Temp" (cuanto más baja es la temperatura, más probable es que las precipitaciones sean altas).
#
# La tercera gráfica por su parte, no proporciona mucha información nueva sobre la relación entre los distintos parametros; pero a pesar de ello nos ayuda a visualizar mejor algunos de ellos como la relación inversa entre "Neg.Temp" y "Viento" y "Empresas" y "Población" (están casi perfectamente alineadas).
#
# Con respecto a la dispersión de las muestras, esta se hace más significativa en la tercera gráfica en comparación con las dos anteriores. Esto podría estar indicando que en los gráficos 1 y 2 la influencia mutua de las variables es mayor, lo cual es coherente pues PC1 nos aporta casi el 40% de la información.
#
# También se puede apreciar la presencia de valores átipicos en la combinación de PCAs. En el primer gráfico, la gran mayoría de ellos recae en los valores negativos de ambos componentes principales. Tomando el análisis previamente realizado, podemos ubicar las características principales de los "outliers" sin mayor dificultad.
# En el segundo gráfico los "outliers se concentran en el umbral negativo para PC1 y positivo para  PC3 (baja población y número de empresas, muchas precipitaciones, temperatura alta en algunos casos...). Cabe destacar que en ambas gráficas hay una muestra extremadamente alejada del resto en PC1, la cual representa un verdadero valor átipico.
# De la tercera gráfica no podemos extraer mucha información en esto aspecto, pues los puntos están demasiado dispersos y hay demasiados de ellos que se alejan de las flechas. Una posible causa podría ser la ausencia de PC1, ya que implicaría una falta de representatividad. que algunos de los "outliers" presentes es estas gráficas podrían no serlo para el conjunto total muestras (tomando todos los componentes principales).

# %% [markdown]
# En 3 dimensiones queda:

# %%
fig, ax = plt.subplots()
ax = plt.subplot(projection='3d')
ax.scatter(df_pca['PC1'], df_pca['PC2'], df_pca['PC3'])
for i, variable in enumerate(df_std.columns):
    x, y, z = np.zeros(3)
    u, v, w = eigenvectors[i, :3] * 3
    plt.quiver(x, y, z, u, v, w, color='r')

# %% [markdown]
# A continuación repetiremos los procesos anteriores empleando solamente métodos propios de la libreria scikit-learn. El punto crucial de ello es que "sklearn" dispone del objeto PCA, lo cual ayuda a simplificar en gran manera todos los cálculos que serán realizados.

# %%
from sklearn.decomposition import PCA

# 1. Estandarizar los datos
scaler = StandardScaler()
df_std = scaler.fit_transform(df)
# Out:
#              Autovalor  Varianza explicada(%)  Varianza Acumulada(%)
# Componentes
# PC1               2.73                  38.97                  38.97
# PC2               1.51                  21.60                  60.58
# PC3               1.39                  19.93                  80.51
# PC4               0.89                  12.74                  93.25
# PC5               0.35                   4.95                  98.20
# PC6               0.10                   1.43                  99.64
# PC7               0.03                   0.36                 100.00

# %% [markdown]
# Al igual que en el primer apartado, empleamos "StandardScaler" para estandarizar los datos; por lo que el código no difiere en nada comparado al anterior.

# %%
# 2. Aplicar PCA y calcular porcentaje de varianza explicada y varianza acumulada
pca = PCA()
pca.fit(df_std)

variance_perc = pca.explained_variance_ratio_ * 100
acc_variance_perc = variance_perc.cumsum()
comp_index = pd.Index([f'PC{i+1}' for i in range(len(eigenvalues))], name='Componentes')

df_variance = pd.DataFrame({
    'Autovalor': eigenvalues,
    'Varianza explicada(%)': variance_perc,
    'Varianza Acumulada(%)': acc_variance_perc},
    index=comp_index)

with Notation2Decimal():
    print(df_variance)

# %% [markdown]
# A diferencia del apartado anterior, este fragmento de código sí presenta diferencias notables con respecto al método anteriormente empleado en el cálculo de autovalores, autovectores y componentes principales.
#
# En el apartado anterior se empleó la librería NumPy para realizar los calculos, mientras que en este fragmento se utiliza la librería cikit-learn la cual, como hemos mencionado anteriormente, cuenta con la clase propia PCA.
#
# Con "***pca = PCA()***" creamos una instancia del objeto PCA el cual es utilizado para realizar el Análisis de Componentes Principales (PCA) en el conjunto de datos. Por su parte "**pca.fit(df_std)**" ajusta el modelo PCA al conjunto de datos estandarizado **df_std**. Durante dicho proceso, PCA calcula también los autovalores y autovectores de la matriz de covarianza de df_std.
#
# La instancia PCA tiene también el atributo **explained_variance_ratio_** que contiene los porcentajes de varianza explicada por cada componente principal ( los multiplicamos por 100 para mostrarlos en forma de porcentaje).
#
# La varianza acumulada se calcula con **acc_variance_perc**, que se limita a sumar las varianzas explicadas de los componentes anteriores.
#
# **comp_index** se utiliza para indexar los datos y etiquetar las componentes principales (PC1, PC2, PC3,...etc).
#
# Finalmente, se crea un Dataframe de Pandas con **f_variance = pd.DataFrame(...)** que contiene todos los parámetros de cada componente pricipal.
#
#  Como se puede apreciar, los resultados obtenidos son numericamente identicos a los obtenidos mediante el otro código. Contestando a las cuestiones anteriores, con 2 componentes estariamos perdiendo un 39,42% de la información y con 3 componentes un 19,49%.
#
#  Aun con todo, cabe recalcar que el objeto PCA de scikit-learn además de simplificar enormemente el proceso de cálculo,ofrece también funcionalidades adicionales como la capacidad de realizar transformaciones de datos basadas en los componentes principales.

# %%
# 3. Representar gráficamente las ciudades en un diagrama de dispersión en 3D
principal_components = pca.transform(df_std)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')


# Scatter plot
ax.scatter(principal_components[:, 0], principal_components[:, 1], principal_components[:, 2], alpha=0.5)


# Etiquetar los ejes
ax.set_xlabel('Componente Principal 1')
ax.set_ylabel('Componente Principal 2')
ax.set_zlabel('Componente Principal 3')
ax.set_title('PCA de Ciudades')


# Mostrar el gráfico
plt.show()

# %% [markdown]
# Por último tenemos la representación gráfica. Teniendo que "**pca**" es un objeto PCA que ya ha sido ajustado previamente al conjunto de datos estandarizado **df_std**, podemos utilizar el metódo **transform()** para transformar los datos originales en el espacio de las componentes principales.
#
# El resto del proceso se basa simplemente en crear un gráfico de dispersión tridimensional utilizando Matplotlib, donde las coordenadas de cada punto son las componentes principales obtenidas.
